# %% [markdown]
# Problem 1: Social Media – Post Engagement Analyzer
#
# Problem Statement:
#
# Create a function to analyze engagement on a social media post.
#
# Rules:
#
# Calculate total likes
#
# If Total Likes ≥ 1000 → Viral Post
#
# Otherwise → Normal Engagement
#
# Real-Time Use:
#
# Social media analytics platforms
#
# Marketing dashboards
#
# Hint:
#
# Use function
#
# Use loop for calculations
#
# Expected Output Format:
#
# Total Likes: 1050
#
# Post Status: Viral Post

# %%
def post_engagement_analyzer(likes_list):
    total_likes = 0
    for like in likes_list:
        total_likes += like
    print("Total Likes:", total_likes)
    if total_likes >= 1000:
        print("Post Status: Viral Post")
    else:
        print("Post Status: Normal Engagement")
likes = [200, 150, 300, 250, 150]
post_engagement_analyzer(likes)
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %% [markdown]
# Problem 2: Healthcare – Medicine Stock Alert System
#
# Problem Statement:
#
# Create a function to monitor medicine stock levels.
#
# Rules:
#
# Stock < 10 → Low Stock Alert
#
# Stock ≥ 10 → Stock Sufficient
#
# Real-Time Use:
#
# Pharmacy management systems
#
# Hospital inventory tracking
#
# Hint:
#
# Use function
#
# Use conditional logic
#
# Expected Output Format:
#
# Medicine Stock: 6
#
# Status: Low Stock Alert

# %%
def check_medicine_stock(medicine_name, stock):
    print(f"Medicine: {medicine_name}")
    print(f"Medicine Stock: {stock}")
    if stock < 10:
        print("Status: Low Stock Alert")
    else:
        print("Status: Stock Sufficient")
check_medicine_stock("Paracetamol", 6)
check_medicine_stock("Ibuprofen", 15)
# Out:
# Medicine: Paracetamol
# Medicine Stock: 6
# Status: Low Stock Alert
# Medicine: Ibuprofen
# Medicine Stock: 15
# Status: Stock Sufficient

# %% [markdown]
# Problem 3: Agriculture – Rainfall Adequacy Checker
#
# Problem Statement:
#
# Create a function that analyzes seasonal rainfall data.
#
# Rules:
#
# Calculate average rainfall
#
# Average ≥ required level → Adequate
# Rainfall
#
# Otherwise → Inadequate Rainfall
#
# Real-Time Use:
#
# Climate monitoring systems
#
# Irrigation planning tools
#
# Hint:
#
# Use function
# Use loop and math operations
#
# Expected Output Format:
#
# Average Rainfall: 72
#
# Rainfall Status: Adequate Rainfall

# %%
def rainfall_checker(rainfall_data, required_level):
    total_rainfall = 0
    n = len(rainfall_data)
    for rainfall in rainfall_data:
        total_rainfall += rainfall
    average_rainfall = total_rainfall / n
    print(f"Average Rainfall: {average_rainfall:.2f}")
    if average_rainfall >= required_level:
        print("Rainfall Status: Adequate Rainfall")
    else:
        print("Rainfall Status: Inadequate Rainfall")
seasonal_rainfall = [80, 70, 65, 75, 70]
required_rainfall = 70
rainfall_checker(seasonal_rainfall, required_rainfall)
# Out:
# Average Rainfall: 72.00
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# Problem 4: Social Media – Duplicate Account Detection
#
# Problem Statement:
#
# Create a function to detect duplicate usernames in a system.
#
# Rules:
#
# If duplicates exist → Flag accounts
#
# Else → Accounts are unique
#
# Real-Time Use:
#
# Platform moderation
#
# Fraud detection systems
#
# Hint:
#
# Use function
#
# Use set data structure
#
# Expected Output Format:
#
# Duplicate Accounts Found: Yes

# %%
def detect_duplicate_accounts(usernames):
    unique_usernames = set(usernames)
    if len(unique_usernames) < len(usernames):
        print("Duplicate Accounts Found: Yes")
    else:
        print("Duplicate Accounts Found: No")
user_list = ["alice", "bob", "charlie", "alice", "david"]
detect_duplicate_accounts(user_list)
user_list2 = ["alice", "bob", "charlie", "david"]
detect_duplicate_accounts(user_list2)
# Out:
# Duplicate Accounts Found: Yes
# Duplicate Accounts Found: No

# %% [markdown]
# Problem 5: Healthcare – Appointment Eligibility Checker:
#
# Problem Statement:
#
# Create a function to check whether a patient is eligible for an appointment slot.
#
# Rules:
#
# Age ≥ 18 → Eligible
#
# Age < 18 → Not Eligible
#
# Real-Time Use:
#
# Hospital appointment systems
#
# Healthcare portals
#
# Hint:
#
# Use function
#
# Use condition checks
#
# Expected Output Format:
#
# Patient Age: 21
#
# Eligibility Status: Eligible

# %%
def check_appointment_eligibility(patient_name, age):
    print(f"Patient Name: {patient_name}")
    print(f"Patient Age: {age}")
    if age >= 18:
        print("Eligibility Status: Eligible")
    else:
        print("Eligibility Status: Not Eligible")
check_appointment_eligibility("Rahul", 21)
check_appointment_eligibility("Ananya", 15)
# Out:
# Patient Name: Rahul
# Patient Age: 21
# Eligibility Status: Eligible
# Patient Name: Ananya
# Patient Age: 15
# Eligibility Status: Not Eligible

# %% [markdown]
# Problem 6: Agriculture – Premium Crop Price Filter
#
# Problem Statement:
#
# Create a function that filters crop prices above a premium threshold.
#
# Rules:
#
# Price > ₹2000 → Premium Crop
#
# Else → Regular Crop
#
# Real-Time Use:
#
# Market analytics
#
# Export pricing systems
#
# Hint:
#
# Use function
#
# Use list filtering logic
#
# Expected Output Format:
#
# Premium Crops: [2500, 3200]

# %%
def premium_crop_filter(crop_prices, premium_threshold=2000):
    premium_crops = [price for price in crop_prices if price > premium_threshold]
    print("Premium Crops:", premium_crops)
crop_prices = [1500, 2500, 1800, 3200, 2000]
premium_crop_filter(crop_prices)
# Out:
# Premium Crops: [2500, 3200]

# %% [markdown]
# Problem 7: System Monitoring – Application Health Checker
#
# Problem Statement:
#
# Create a function to evaluate application health based on error count.
#
# Rules:
#
# Errors = 0 → Healthy
#
# Errors ≤ 5 → Minor Issues
#
# Errors > 5 → Critical Issues
#
# Real-Time Use:
#
# System monitoring tools
#
# IT operations dashboards
#
# Hint:
#
# Use function
#
# Use conditional statements
#
# Expected Output Format
#
# Error Count: 7
#
# System Status: Critical Issues

# %%
def application_health_checker(app_name, error_count):
    print(f"Application: {app_name}")
    print(f"Error Count: {error_count}")
    if error_count == 0:
        status = "Healthy"
    elif error_count <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    print(f"System Status: {status}")
application_health_checker("InventoryApp", 7)
application_health_checker("LoginService", 3)
application_health_checker("AnalyticsTool", 0)
# Out:
# Application: InventoryApp
# Error Count: 7
# System Status: Critical Issues
# Application: LoginService
# Error Count: 3
# System Status: Minor Issues
# Application: AnalyticsTool
# Error Count: 0
# System Status: Healthy

# %% [markdown]
# Problem 8: Banking – Daily Transaction Limit Checker
#
# Problem Statement:
#
# Create a function to validate daily transaction amount.
#
# Rules:
#
# Daily limit = ₹50,000
#
# Amount within limit → Approved
#
# Amount exceeds limit → Rejected
#
# Real-Time Use:
#
# Banking systems
#
# Fraud prevention systems
#
# Hint:
#
# Use function
#
# Use conditional logic
#
# Expected Output Format:
#
# Transaction Amount: 60000
#
# Transaction Status: Rejected

# %%
def transaction_limit_checker(transaction_amount, daily_limit=50000):
    print(f"Transaction Amount: {transaction_amount}")
    if transaction_amount <= daily_limit:
        print("Transaction Status: Approved")
    else:
        print("Transaction Status: Rejected")
transaction_limit_checker(60000)
transaction_limit_checker(45000)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected
# Transaction Amount: 45000
# Transaction Status: Approved

# %% [markdown]
# Problem 9: E-Learning – Student Attendance Eligibility System
#
# Problem Statement:
#
# Create a function to calculate attendance percentage and check exam eligibility.
#
# Rules:
#
# Attendance ≥ 75% → Eligible
#
# Attendance < 75% → Not Eligible
#
# Real-Time Use:
#
# Learning management systems
#
# Internship tracking platforms
#
# Hint:
#
# Use function
#
# Use list and loop
#
# Expected Output Format:
#
# Attendance Percentage: 80.0
#
# Exam Eligibility: Eligible

# %%
def attendance_eligibility(attendance_list):
    total_classes = len(attendance_list)
    attended_classes = 0
    for status in attendance_list:
        if status.upper() == "P":
            attended_classes += 1
    attendance_percentage = (attended_classes / total_classes) * 100
    print(f"Attendance Percentage: {attendance_percentage:.1f}")
    if attendance_percentage >= 75:
        print("Exam Eligibility: Eligible")
    else:
        print("Exam Eligibility: Not Eligible")
attendance_list = ["P", "A", "P", "P", "P", "A", "P", "P", "P", "A"]
attendance_eligibility(attendance_list)
# Out:
# Attendance Percentage: 70.0
# Exam Eligibility: Not Eligible

# %% [markdown]
# Problem 10: Smart Electricity Bill Analyzer
#
# Problem Statement:
#
# You are building a smart electricity billing system for residential users.
# Create a function that calculates the electricity bill and classifies usage level based on units consumed.
#
# Billing Rules:
#
# First 100 units → ₹3 per unit
#
# Next 100 units (101–200) → ₹5 per unit
#
# Above 200 units → ₹7 per unit
#
# Usage Classification:
#
# Total bill < ₹500 → Low Usage
#
# ₹500 – ₹1500 → Moderate Usage
#
# ₹1500 → High Usage
#
# Real-Time Use:
#
# Smart meter systems
#
# Electricity board billing software
#
# Energy consumption analytics
#
# Hint:
#
# Use function to calculate bill
#
# Use conditional logic for slabs
#
# Use return values (bill and usage status)

# %%
def electricity_bill_analyzer(units_consumed):
    if units_consumed <= 100:
        bill = units_consumed * 3
    elif units_consumed <= 200:
        bill = (100 * 3) + ((units_consumed - 100) * 5)
    else:
        bill = (100 * 3) + (100 * 5) + ((units_consumed - 200) * 7)
    if bill < 500:
        usage_status = "Low Usage"
    elif bill <= 1500:
        usage_status = "Moderate Usage"
    else:
        usage_status = "High Usage"
    return bill, usage_status
units = 250
bill_amount, usage = electricity_bill_analyzer(units)
print(f"Units Consumed: {units}")
print(f"Total Bill: ₹{bill_amount}")
print(f"Usage Classification: {usage}")
# Out:
# Units Consumed: 250
# Total Bill: ₹1150
# Usage Classification: Moderate Usage
